# %% [markdown]
# #### Importing required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# #### Exploring data

# %%
df_data_1 = pd.read_csv('./data/connecticut/ct_hartford_2020_04_01.csv')

df_data_1.head()
# Out:
#   raw_row_number        date      time                        location  \
# 0              1  2013-10-13  15:21:00            LINNMORE ST AT ROGER
# 1              2  2013-10-24  01:12:00  HAWTHORN STREET @ IMLAY STREET
# 2              3  2013-10-26  10:06:00                NEW PARK MIRRILL
# 3              4  2013-10-26  18:06:00         nfew park at merrill st
# 4              5  2013-10-26  19:56:00            SUMMIT ST AT ZION ST
#
#          lat        lng     district  subject_age subject_race subject_sex  \
# 0  41.732189 -72.699760   SOUTH WEST         38.0     hispanic      female
# 1  41.764621 -72.695362  ASYLUM HILL         20.0        black        male
# 2  41.747837 -72.712933    PARKVILLE         26.0        white      female
# 3  41.748069 -72.712641    PARKVILLE         26.0        white      female
# 4  41.753945 -72.693278  FROG HOLLOW         39.0        white        male
#
#    ...   outcome contraband_found search_conducted search_vehicle  \
# ...

# %%
df_data_1.columns
# Out:
# Index(['raw_row_number', 'date', 'time', 'location', 'lat', 'lng', 'district',
#        'subject_age', 'subject_race', 'subject_sex', 'officer_id_hash',
#        'department_name', 'type', 'arrest_made', 'citation_issued',
#        'warning_issued', 'outcome', 'contraband_found', 'search_conducted',
#        'search_vehicle', 'search_basis', 'reason_for_stop',
#        'raw_subject_race_code', 'raw_subject_ethnicity_code',
#        'raw_search_authorization_code', 'raw_intervention_disposition_code'],
#       dtype='object')

# %% [markdown]
# ## Outcome of stop and search race-wise

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style="darkgrid")
sns.set_palette("hls", 3)

# %%
sns.countplot(x = df_data_1['outcome'], hue="subject_race", data=df_data_1)

# %% [markdown]
# ## Search conducted race-wise

# %%
sns.countplot(x = 'search_conducted', hue="subject_race", data=df_data_1)

# %% [markdown]
# ## Search basis race-wise

# %%
sns.countplot(x = 'search_basis', hue="subject_race", data=df_data_1)

# %% [markdown]
# ## Reason for stop race-wise

# %%
a1_dim = (45, 5)
fig, ax = plt.subplots(figsize=a1_dim)
sns.countplot(x = 'reason_for_stop', hue="subject_race", data=df_data_1, ax = ax)

# %% [markdown]
# ## Arrests made race-wise

# %%
sns.countplot(x = 'arrest_made', hue="subject_race", data=df_data_1)

# %% [markdown]
# #### Arrests made race-wise results

# %%
ar_race_wise = df_data_1[['arrest_made','subject_race']]

# %% [markdown]
# ## Citation issued race-wise

# %%
sns.countplot(x = 'citation_issued', hue="subject_race", data=df_data_1)

# %% [markdown]
# ## Warning issued race-wise

# %%
sns.countplot(x = 'warning_issued', hue="subject_race", data=df_data_1)

# %% [markdown]
# # Statewide Data Analysis

# %%
df_data_2 = pd.read_csv('./data/ct_statewide_2020_04_01.csv')
df_data_2.head()
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (14,15,16,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   raw_row_number        date      time                          location  lat  \
# 0           1121  2013-10-01  00:13:00  GREENWOOD AVE/DURANT AVE, BETHEL  NaN
# 1            762  2013-10-01  00:00:00          GREENWOOD AVENUE, BETHEL  NaN
# 2            520  2013-10-01  10:06:00   GREENWOOD AVE/RECTOR ST, BETHEL  NaN
# 3            820  2013-10-01  18:04:00           STONY HILL ROAD, BETHEL  NaN
# 4            521  2013-10-01  17:45:00           STONY HILL ROAD, BETHEL  NaN
#
#    lng       county_name  subject_age            subject_race subject_sex  \
# 0  NaN  Fairfield County         50.0  asian/pacific islander        male
# 1  NaN  Fairfield County         34.0                   white        male
# ...

# %%
sns.countplot(x = df_data_1['outcome'], hue="subject_race", data=df_data_2)

# %%
sns.countplot(x = 'citation_issued', hue="subject_race", data=df_data_2)

# %%
percentage_black_citation = df_data_2.loc[df_data_2['subject_race']=='black', 'citation_issued'].sum() / df_data_2['citation_issued'].sum()

# %%
print("PERCENTAGE OF CITATION FOR BLACK PEOPLE:", percentage_black_citation*100)
# Out:
# PERCENTAGE OF CITATION FOR BLACK PEOPLE: 13.044808758815812

# %%
percentage_white_citation = df_data_2.loc[df_data_2['subject_race']=='white', 'citation_issued'].sum() / df_data_2['citation_issued'].sum()
print("PERCENTAGE OF CITATION FOR WHITE PEOPLE:", percentage_white_citation*100)
# Out:
# PERCENTAGE OF CITATION FOR WHITE PEOPLE: 71.45582385016384
