# %%
import os

# %%
import pandas as pd
# %matplotlib notebook
# %matplotlib notebook
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def percent_ethinicity(inputcsv, column1, column2, column3=None, column4=None, column5=None,column6=None):
    df = pd.read_csv(inputcsv)
    df[column2] = df[column2].astype(int)
    df[column3] = df[column3].astype(int)
    df[column5] = df[column5].astype(int)
    df[column6] = df[column6].astype(int)  
    
    df_test = df.groupby([column1])[column4].value_counts(normalize=True).mul(100).unstack(column4).fillna(0)
   
    #value_count_df_col = 
    df1 = df[[column1, column2, column3, column5, column6]]
    groupped_data = df1.groupby([column1], as_index=False).agg({column2:'mean',  column3:'mean', column5:'mean', column6:'mean'})
    groupped_data[column2] = 100 * groupped_data[column2]
    groupped_data[column3] = 100 * groupped_data[column3]
    groupped_data[column5] = 100 * groupped_data[column5]
    groupped_data[column6] = 100 * groupped_data[column6]
    return df, groupped_data, df_test

# %%
racecol = "subject_race"
column2 = "search_person"
column3 = "search_vehicle"
datecolumn = "date"
column4 = "raw_vehicle_search_search_based_on"
column5 = "search_conducted"
column6 = "frisk_performed"
inputcsv = os.path.join("tx_austin_2020_04_01.csv")

# %%
orig_df, grouped_data, df_test = percent_ethinicity(inputcsv, racecol, column2, column3, column4, column5, column6)

# %%
grouped_data
# Out:
#              subject_race  search_person  search_vehicle  search_conducted  \
# 0  asian/pacific islander       1.169591        0.782259          1.450596
# 1                   black       6.098944        4.146618          7.011504
# 2                hispanic       4.836094        3.113528          5.693746
# 3                   other       2.475248        0.952018          2.779893
# 4                 unknown       2.392344        1.531100          2.870813
# 5                   white       2.082012        1.363511          2.527065
#
#    frisk_performed
# 0         0.820232
# 1         3.399978
# 2         3.109494
# 3         1.751714
# 4         1.754386
# 5         1.459759

# %%
df_test
# Out:
# raw_vehicle_search_search_based_on    CONSENT  \
# subject_race
# asian/pacific islander              22.972973
# black                               23.692636
# hispanic                            29.368451
# other                               23.529412
# unknown                             20.000000
# white                               35.268888
#
# raw_vehicle_search_search_based_on  CONTRABAND/EVIDENCE IN PLAIN VIEW  \
# subject_race
# asian/pacific islander                                       0.000000
# black                                                        1.209534
# hispanic                                                     1.869159
# other                                                        0.000000
# unknown                                                      0.000000
# white                                                        1.022765
#
# raw_vehicle_search_search_based_on  FRISK FOR SAFETY  INCIDENTAL TO ARREST  \
# subject_race
# asian/pacific islander                     37.837838              0.000000
# black                                      17.467094              0.604767
# hispanic                                   18.804871              0.821297
# other                                      11.764706              0.000000
# unknown                                    45.000000              2.500000
# white                                      26.129990              1.055757
#
# raw_vehicle_search_search_based_on  INVENTORY OF TOWED VEHICLE  PROBABLE CAUSE
# subject_race
# asian/pacific islander                                4.054054       35.135135
# black                                                 0.284596       56.741373
# hispanic                                              0.566412       48.569810
# other                                                 0.000000       64.705882
# unknown                                               0.000000       32.500000
# white                                                 0.824810       35.697790

# %%
orig_df[1:20]
# Out:
#    raw_row_number        date  subject_age            subject_race  \
# 1            4819  2006-03-21         21.0                   white
# 2            4820  2006-03-21         43.0                   black
# 3            4821  2006-04-20         46.0                hispanic
# 4            4822  2006-03-21         25.0                   white
# 5            4824  2006-04-20         65.0                   white
# 6            4823  2006-04-20         65.0                   white
# 7            4826  2006-04-20         25.0                hispanic
# 8            4825  2006-04-20         25.0                hispanic
# 9            4827  2006-03-21         49.0                   white
# 10           4828  2006-03-21         36.0                   white
# 11           4829  2006-04-18         42.0                   white
# 12           4830  2006-04-18         42.0                   white
# 13           4831  2006-04-20         45.0                hispanic
# 14            142  2006-01-07         26.0  asian/pacific islander
# 15           4832  2006-03-21         42.0                   white
# 16           4833  2006-04-19         40.0                   white
# 17           4834  2006-04-19         40.0                   white
# 18           4835  2006-03-21         30.0  asian/pacific islander
# 19           4836  2006-04-19         40.0                   white
#
#    subject_sex officer_id_hash       type contraband_found contraband_drugs  \
# 1         male      46f8ed46eb  vehicular              NaN              NaN
# 2       female      0d1d4fb150  vehicular              NaN              NaN
# 3         male      c70bca9788        NaN              NaN              NaN
# 4         male      e3f693e058  vehicular              NaN              NaN
# 5         male      c70bca9788        NaN              NaN              NaN
# 6         male      c70bca9788        NaN              NaN              NaN
# 7         male      c70bca9788        NaN              NaN              NaN
# 8         male      c70bca9788        NaN              NaN              NaN
# 9         male      60a3625dbd  vehicular              NaN              NaN
# 10        male      60a3625dbd  vehicular              NaN              NaN
# 11        male      c70bca9788        NaN              NaN              NaN
# 12        male      c70bca9788        NaN              NaN              NaN
# 13        male      8fc0622dc5        NaN              NaN              NaN
# 14        male      59c9092a79  vehicular            False            False
# 15      female      ce995d2f53  vehicular              NaN              NaN
# 16        male      13e2078d7d  vehicular              NaN              NaN
# 17        male      13e2078d7d  vehicular              NaN              NaN
# 18        male      ce995d2f53  vehicular              NaN              NaN
# 19        male      13e2078d7d  vehicular              NaN              NaN
#
#    contraband_weapons  ...  vehicle_year  raw_ethnicity  \
# 1                 NaN  ...        2000.0            NaN
# 2                 NaN  ...        2003.0            NaN
# 3                 NaN  ...        1994.0              H
# 4                 NaN  ...        2002.0            NaN
# 5                 NaN  ...        1991.0            NaN
# 6                 NaN  ...        1995.0            NaN
# 7                 NaN  ...        1983.0              H
# 8                 NaN  ...        1994.0              H
# 9                 NaN  ...        2000.0            NaN
# 10                NaN  ...        1996.0            NaN
# 11                NaN  ...        2000.0            NaN
# 12                NaN  ...        2000.0            NaN
# 13                NaN  ...        1995.0              H
# 14              False  ...        1998.0            NaN
# 15                NaN  ...        1988.0            NaN
# 16                NaN  ...           NaN            NaN
# 17                NaN  ...           NaN            NaN
# 18                NaN  ...        2006.0            NaN
# 19                NaN  ...           NaN            NaN
#
#     raw_person_search_search_based_on  raw_person_search_search_discovered  \
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# 5                                 NaN                                  NaN
# 6                                 NaN                                  NaN
# 7                                 NaN                                  NaN
# 8                                 NaN                                  NaN
# 9                                 NaN                                  NaN
# 10                                NaN                                  NaN
# 11                                NaN                                  NaN
# 12                                NaN                                  NaN
# 13                                NaN                                  NaN
# 14                                NaN                                  NaN
# 15                                NaN                                  NaN
# 16                                NaN                                  NaN
# 17                                NaN                                  NaN
# 18                                NaN                                  NaN
# 19                                NaN                                  NaN
#
#    raw_person_searched raw_vehicle_search_search_based_on  \
# 1               NO = -                                NaN
# 2               NO = -                                NaN
# 3               NO = -                                NaN
# 4               NO = -                                NaN
# 5               NO = -                                NaN
# 6               NO = -                                NaN
# 7               NO = -                                NaN
# 8               NO = -                                NaN
# 9               NO = -                                NaN
# 10              NO = -                                NaN
# 11              NO = -                                NaN
# 12              NO = -                                NaN
# 13              NO = -                                NaN
# 14             YES = -                                NaN
# 15              NO = -                                NaN
# 16              NO = -                                NaN
# 17              NO = -                                NaN
# 18              NO = -                                NaN
# 19              NO = -                                NaN
#
#    raw_vehicle_search_search_discovered raw_vehicle_searched  \
# 1                                   NaN                NO= -
# 2                                   NaN                NO= -
# 3                                   NaN                NO= -
# 4                                   NaN                NO= -
# 5                                   NaN                NO= -
# 6                                   NaN                NO= -
# 7                                   NaN                NO= -
# 8                                   NaN                NO= -
# 9                                   NaN                NO= -
# 10                                  NaN                NO= -
# 11                                  NaN                NO= -
# 12                                  NaN                NO= -
# 13                                  NaN                NO= -
# 14                                  NaN              YES = -
# 15                                  NaN                NO= -
# 16                                  NaN                NO= -
# 17                                  NaN                NO= -
# 18                                  NaN                NO= -
# 19                                  NaN                NO= -
#
#    raw_race_description  raw_street_check_description
# 1                 WHITE                       WARNING
# 2                 BLACK                       WARNING
# 3                 WHITE                       WARNING
# 4                 WHITE                       WARNING
# 5                 WHITE                       WARNING
# 6                 WHITE                       WARNING
# 7                 WHITE                       WARNING
# 8                 WHITE                       WARNING
# 9                 WHITE                       WARNING
# 10                WHITE                       WARNING
# 11                WHITE                       WARNING
# 12                WHITE                       WARNING
# 13                WHITE                       WARNING
# 14                ASIAN                       WARNING
# 15                WHITE                       WARNING
# 16                WHITE                       WARNING
# 17                WHITE                       WARNING
# 18                ASIAN                       WARNING
# 19                WHITE                       WARNING
#
# [19 rows x 29 columns]

# %%
def plot_perc(dataframe, col1):
    dataframe = dataframe.set_index(col1)
    dataframe.plot(kind = "bar",sort_columns=True)
    plt.title("search pecentage across race")
    plt.xticks(fontsize=10)
    plt.tight_layout()
    plt.savefig(inputcsv[:-4] + ".png")

# %%
plot_perc
# Out:
# <function __main__.plot_perc(dataframe, col1)>

# %%
plot_perc(grouped_data, racecol)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
orig_df["raw_vehicle_search_search_based_on"].value_counts()
# Out:
# PROBABLE CAUSE                       4442
# CONSENT                              2801
# FRISK FOR SAFETY                     1995
# CONTRABAND/EVIDENCE IN PLAIN VIEW     131
# INCIDENTAL TO ARREST                   79
# INVENTORY OF TOWED VEHICLE             56
# Name: raw_vehicle_search_search_based_on, dtype: int64

# %%
#df_test = df_test.set_index(racecol)
df_test.plot(kind = "bar",sort_columns=True)
plt.title("vehicle search based on")
plt.xticks(fontsize=10)
plt.tight_layout()
plt.savefig(inputcsv[:-4]+"_violation" + ".png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
orig_df.dropna(axis=0,how="any", subset = ["raw_vehicle_search_search_based_on"], inplace =True)
